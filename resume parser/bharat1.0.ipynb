# %% [markdown]
# # CODE IMPLEMENTATION

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\s mohammed javeed\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: click in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from nltk) (1.3.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: colorama in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from click->nltk) (0.4.5)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Download the necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Sample job description
job_description = """
We are looking for a Software Engineer with experience in Python and Django.
The ideal candidate should be proficient in web development and have a strong
knowledge of database management systems. Knowledge of HTML, CSS, and JavaScript
is also desirable. The candidate should be able to work in a team and have excellent
communication skills.
"""

# Keywords extracted from the job description
job_keywords = set(word_tokenize(job_description.lower()))

# Preprocess the keywords by removing stopwords and stemming
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()
job_keywords = [stemmer.stem(word) for word in job_keywords if word not in stop_words]

def parse_resume(resume_text, job_keywords):
    # Tokenize the resume text and preprocess it
    resume_tokens = set(word_tokenize(resume_text.lower()))
    resume_keywords = [stemmer.stem(word) for word in resume_tokens if word not in stop_words]

    # Calculate the number of matched keywords
    num_matched_keywords = len(set(resume_keywords) & set(job_keywords))

    return num_matched_keywords

# Sample candidate resumes
resume1 = """
I am a Software Engineer with 3 years of experience in Python and Django.
I have worked on various web development projects and managed database systems.
Familiar with HTML, CSS, and JavaScript. Excellent team player and communicator.
"""

resume2 = """
Experienced Python developer skilled in Django and web development.
Extensive knowledge of database management and system architecture.
Proficient in HTML, CSS, and JavaScript. Great team player with strong communication skills.
"""

# Parse the resumes and find the best candidate
resumes = [resume1, resume2]

scores = {}
for i, resume in enumerate(resumes):
    score = parse_resume(resume, job_keywords)
    scores[f"Resume {i+1}"] = score

best_candidate = max(scores, key=scores.get)

print("Resume Scores:", scores)
print("Best Candidate:", best_candidate)
# Out:
# Resume Scores: {'Resume 1': 19, 'Resume 2': 18}
# Best Candidate: Resume 1
# [nltk_data] Downloading package punkt to C:\Users\S MOHAMMED
# [nltk_data]     JAVEED\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\S MOHAMMED
# [nltk_data]     JAVEED\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # the below code is gui implementation

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from tkinter import Tk, Label, Text, Button, Entry, Frame

# Download the necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Sample job description (You can modify this as needed)
job_description = """
We are looking for a Software Engineer with experience in Python and Django.
The ideal candidate should be proficient in web development and have a strong
knowledge of database management systems. Knowledge of HTML, CSS, and JavaScript
is also desirable. The candidate should be able to work in a team and have excellent
communication skills.
"""

# Keywords extracted from the job description
job_keywords = set(word_tokenize(job_description.lower()))

# Preprocess the keywords by removing stopwords and stemming
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()
job_keywords = [stemmer.stem(word) for word in job_keywords if word not in stop_words]

# Function to parse a single resume
def parse_resume(resume_text):
    # Tokenize the resume text and preprocess it
    resume_tokens = set(word_tokenize(resume_text.lower()))
    resume_keywords = [stemmer.stem(word) for word in resume_tokens if word not in stop_words]

    # Calculate the number of matched keywords
    num_matched_keywords = len(set(resume_keywords) & set(job_keywords))

    return num_matched_keywords
def process_resumes():
    num_resumes = int(num_resumes_entry.get())
    result_textbox.delete("1.0", "end")

    highest_score = 0
    best_candidates = []

    for i in range(num_resumes):
        resume_text = resume_textboxes[i].get("1.0", "end-1c")
        score = parse_resume(resume_text)
        result_textbox.insert("end", f"Resume {i+1} Score: {score}\n")
        if score > highest_score:
            highest_score = score
            best_candidates = [i + 1]
        elif score == highest_score:
            best_candidates.append(i + 1)

    if best_candidates:
        result_textbox.insert("end", f"Highest Score: {highest_score}\n")
        result_textbox.insert("end", f"Candidate(s) with the highest score: {', '.join(map(str, best_candidates))}\n")
    else:
        result_textbox.insert("end", "No candidates found.")

# Create the main application window
root = Tk()
root.title("Resume Parser")
root.geometry("500x600")

# Job description label
job_desc_label = Label(root, text="Job Description:")
job_desc_label.pack()

# Job description textbox (read-only)
job_desc_textbox = Text(root, width=60, height=6)
job_desc_textbox.insert("end", job_description)
job_desc_textbox.config(state="disabled")
job_desc_textbox.pack()

# Input field for the number of resumes
num_resumes_label = Label(root, text="Enter the number of resumes:")
num_resumes_label.pack()

num_resumes_entry = Entry(root)
num_resumes_entry.pack()

# List to hold resume textboxes
resume_textboxes = []

# Function to dynamically add resume entry fields based on user input
def add_resume_fields():
    num_resumes = int(num_resumes_entry.get())

    # Clear existing resume textboxes
    for textbox in resume_textboxes:
        textbox.pack_forget()

    resume_textboxes.clear()

    # Create and display resume entry fields
    for i in range(num_resumes):
        resume_label = Label(root, text=f"Enter Candidate Resume {i+1}:")
        resume_label.pack()

        resume_textbox = Text(root, width=60, height=6)
        resume_textbox.pack()

        resume_textboxes.append(resume_textbox)

    # Update result textbox position
    result_label.pack()
    result_textbox.pack()

# Add a button to update the resume entry fields dynamically
add_resumes_button = Button(root, text="Add Resumes", command=add_resume_fields)
add_resumes_button.pack()

# Frame to hold process button
button_frame = Frame(root)
button_frame.pack()

# Process button
process_button = Button(button_frame, text="Process Resumes", command=process_resumes)
process_button.pack()

# Result label and textbox
result_label = Label(root, text="Results:")
result_textbox = Text(root, width=60, height=10)

root.mainloop()
# Out:
# [nltk_data] Downloading package punkt to C:\Users\S MOHAMMED
# [nltk_data]     JAVEED\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\S MOHAMMED
# [nltk_data]     JAVEED\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !pip  install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.6.0-cp39-cp39-win_amd64.whl (12.3 MB)
#      ---------------------------------------- 12.3/12.3 MB 3.6 MB/s eta 0:00:00
#   Downloading spacy-3.5.4-cp39-cp39-win_amd64.whl (12.2 MB)
#      ---------------------------------------- 12.2/12.2 MB 5.1 MB/s eta 0:00:00
#   Downloading spacy-3.5.3-cp39-cp39-win_amd64.whl (12.2 MB)
#      ---------------------------------------- 12.2/12.2 MB 4.7 MB/s eta 0:00:00
# Collecting typer<0.8.0,>=0.3.0
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Collecting spacy
#   Downloading spacy-3.5.2-cp39-cp39-win_amd64.whl (12.2 MB)
#      ---------------------------------------- 12.2/12.2 MB 5.9 MB/s eta 0:00:00
#   Downloading spacy-3.5.1-cp39-cp39-win_amd64.whl (12.2 MB)
#      ---------------------------------------- 12.2/12.2 MB 6.3 MB/s eta 0:00:00
#   Downloading spacy-3.5.0-cp39-cp39-win_amd64.whl (12.2 MB)
#      ---------------------------------------- 12.2/12.2 MB 5.5 MB/s eta 0:00:00
#   Downloading spacy-3.4.4-cp39-cp39-win_amd64.whl (11.9 MB)
#      ---------------------------------------- 11.9/11.9 MB 4.2 MB/s eta 0:00:00
# Collecting wasabi<1.1.0,>=0.9.1
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting spacy
#   Downloading spacy-3.4.3-cp39-cp39-win_amd64.whl (11.9 MB)
#      ---------------------------------------- 11.9/11.9 MB 5.6 MB/s eta 0:00:00
#   Downloading spacy-3.4.2-cp39-cp39-win_amd64.whl (11.9 MB)
#      ---------------------------------------- 11.9/11.9 MB 5.2 MB/s eta 0:00:00
#   Downloading spacy-3.4.1-cp39-cp39-win_amd64.whl (11.8 MB)
#      ---------------------------------------- 11.8/11.8 MB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.7-cp39-cp39-win_amd64.whl (483 kB)
#      -------------------------------------- 483.6/483.6 kB 5.0 MB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from spacy) (1.23.5)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp39-cp39-win_amd64.whl (96 kB)
#      ---------------------------------------- 96.8/96.8 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from spacy) (21.3)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp39-cp39-win_amd64.whl (30 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.9-py3-none-any.whl (17 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp39-cp39-win_amd64.whl (18 kB)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.2-py3-none-any.whl (27 kB)
# Requirement already satisfied: jinja2 in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: setuptools in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from spacy) (63.4.1)
# Collecting thinc<8.2.0,>=8.1.0
#   Downloading thinc-8.1.10-cp39-cp39-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 6.7 MB/s eta 0:00:00
# Collecting pathy>=0.3.5
#   Downloading pathy-0.10.2-py3-none-any.whl (48 kB)
#      ---------------------------------------- 48.9/48.9 kB 2.4 MB/s eta 0:00:00
# Collecting spacy
#   Downloading spacy-3.4.0-cp39-cp39-win_amd64.whl (11.8 MB)
#      ---------------------------------------- 11.8/11.8 MB 6.2 MB/s eta 0:00:00
#   Downloading spacy-3.3.3-cp39-cp39-win_amd64.whl (11.8 MB)
#      ---------------------------------------- 11.8/11.8 MB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<4.6.0,>=3.7.4.1 in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from spacy) (4.3.0)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.10-cp39-cp39-win_amd64.whl (7.4 MB)
#      ---------------------------------------- 7.4/7.4 MB 4.7 MB/s eta 0:00:00
# Collecting thinc<8.1.0,>=8.0.14
#   Downloading thinc-8.0.17-cp39-cp39-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      -------------------------------------- 181.6/181.6 kB 5.5 MB/s eta 0:00:00
# Collecting spacy
#   Downloading spacy-3.3.2-cp39-cp39-win_amd64.whl (11.7 MB)
#      ---------------------------------------- 11.7/11.7 MB 4.9 MB/s eta 0:00:00
#   Downloading spacy-3.3.1-cp39-cp39-win_amd64.whl (11.7 MB)
#      ---------------------------------------- 11.7/11.7 MB 5.5 MB/s eta 0:00:00
#   Downloading spacy-3.3.0-cp39-cp39-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 6.7 MB/s eta 0:00:00
#   Downloading spacy-3.2.6-cp39-cp39-win_amd64.whl (11.4 MB)
#      ---------------------------------------- 11.4/11.4 MB 4.7 MB/s eta 0:00:00
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy
#   Downloading spacy-3.2.5-cp39-cp39-win_amd64.whl (11.3 MB)
#      ---------------------------------------- 11.3/11.3 MB 5.5 MB/s eta 0:00:00
#   Downloading spacy-3.2.4-cp39-cp39-win_amd64.whl (11.3 MB)
#      ---------------------------------------- 11.3/11.3 MB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: click<8.1.0 in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from spacy) (8.0.4)
#   Downloading spacy-3.2.3-cp39-cp39-win_amd64.whl (11.3 MB)
#      ---------------------------------------- 11.3/11.3 MB 6.4 MB/s eta 0:00:00
#   Downloading spacy-3.2.2-cp39-cp39-win_amd64.whl (11.3 MB)
#      ---------------------------------------- 11.3/11.3 MB 7.7 MB/s eta 0:00:00
#   Downloading spacy-3.2.1-cp39-cp39-win_amd64.whl (11.8 MB)
#      ---------------------------------------- 11.8/11.8 MB 7.6 MB/s eta 0:00:00
#   Downloading spacy-3.2.0-cp39-cp39-win_amd64.whl (11.7 MB)
#      ---------------------------------------- 11.7/11.7 MB 8.0 MB/s eta 0:00:00
#   Downloading spacy-3.1.7-cp39-cp39-win_amd64.whl (11.2 MB)
#      ---------------------------------------- 11.2/11.2 MB 7.1 MB/s eta 0:00:00
#   Downloading spacy-3.1.6-cp39-cp39-win_amd64.whl (11.2 MB)
#      ---------------------------------------- 11.2/11.2 MB 9.8 MB/s eta 0:00:00
#   Downloading spacy-3.1.5-cp39-cp39-win_amd64.whl (11.2 MB)
#      ---------------------------------------- 11.2/11.2 MB 8.6 MB/s eta 0:00:00
#   Downloading spacy-3.1.4-cp39-cp39-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 9.0 MB/s eta 0:00:00
#   Downloading spacy-3.1.3-cp39-cp39-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 8.1 MB/s eta 0:00:00
#   Downloading spacy-3.1.2-cp39-cp39-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 7.6 MB/s eta 0:00:00
# Collecting typer<0.4.0,>=0.3.0
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Collecting spacy
#   Downloading spacy-3.1.1-cp39-cp39-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 5.6 MB/s eta 0:00:00
#   Downloading spacy-3.1.0-cp39-cp39-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 8.7 MB/s eta 0:00:00
#   Downloading spacy-3.0.9-cp39-cp39-win_amd64.whl (11.1 MB)
#      ---------------------------------------- 11.1/11.1 MB 8.0 MB/s eta 0:00:00
#   Downloading spacy-3.0.8-cp39-cp39-win_amd64.whl (11.1 MB)
#      ---------------------------------------- 11.1/11.1 MB 8.7 MB/s eta 0:00:00
#   Downloading spacy-3.0.7-cp39-cp39-win_amd64.whl (11.5 MB)
#      ---------------------------------------- 11.5/11.5 MB 7.8 MB/s eta 0:00:00
#   Downloading spacy-3.0.6-cp39-cp39-win_amd64.whl (11.5 MB)
#      ---------------------------------------- 11.5/11.5 MB 8.0 MB/s eta 0:00:00
#   Downloading spacy-3.0.5-cp39-cp39-win_amd64.whl (11.4 MB)
#      ---------------------------------------- 11.4/11.4 MB 7.9 MB/s eta 0:00:00
#   Downloading spacy-3.0.4-cp39-cp39-win_amd64.whl (11.4 MB)
#      ---------------------------------------- 11.4/11.4 MB 9.2 MB/s eta 0:00:00
#   Downloading spacy-3.0.3-cp39-cp39-win_amd64.whl (11.4 MB)
#      ---------------------------------------- 11.4/11.4 MB 9.1 MB/s eta 0:00:00
#   Downloading spacy-3.0.2-cp39-cp39-win_amd64.whl (11.4 MB)
#      ---------------------------------------- 11.4/11.4 MB 9.2 MB/s eta 0:00:00
#   Downloading spacy-3.0.1-cp39-cp39-win_amd64.whl (11.4 MB)
#      ---------------------------------------- 11.4/11.4 MB 8.5 MB/s eta 0:00:00
#   Downloading spacy-3.0.0-cp39-cp39-win_amd64.whl (11.4 MB)
#      ---------------------------------------- 11.4/11.4 MB 8.8 MB/s eta 0:00:00
#   Downloading spacy-2.3.9-cp39-cp39-win_amd64.whl (9.1 MB)
#      ---------------------------------------- 9.1/9.1 MB 9.1 MB/s eta 0:00:00
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.6-cp39-cp39-win_amd64.whl (830 kB)
#      -------------------------------------- 830.6/830.6 kB 8.7 MB/s eta 0:00:00
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.7-cp39-cp39-win_amd64.whl (358 kB)
#      -------------------------------------- 358.9/358.9 kB 7.4 MB/s eta 0:00:00
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.14)
# Requirement already satisfied: colorama in c:\users\s mohammed javeed\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.5)
# Installing collected packages: wasabi, plac, cymem, srsly, murmurhash, catalogue, blis, preshed, thinc, spacy
# Successfully installed blis-0.7.10 catalogue-1.0.2 cymem-2.0.7 murmurhash-1.0.9 plac-1.1.3 preshed-3.0.8 spacy-2.3.9 srsly-1.0.7 thinc-7.4.6 wasabi-0.10.1
